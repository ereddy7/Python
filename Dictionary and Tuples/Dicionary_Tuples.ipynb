# %%
# Tuples (ordered, immutable collections)
expences = [1500,1200,1700,800]

# %%
print(expences)
# Out:
# (1500, 1200, 1700, 800)

# %%
expences[1]=900
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 expences[1]=900
#
# TypeError: 'tuple' object does not support item assignment
