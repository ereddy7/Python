# %%
firstname = "eswar"
lname = "reddy"

fullname = firstname + lname

fullname
# Out:
# 'eswarreddy'

# %%
fullname = firstname + " " + lname

fullname
# Out:
# 'eswar reddy'

# %%
age =37
fullname = f"{firstname} {lname} is having {age} years old "
fullname
# Out:
# 'eswar reddy is having 37 years old '

# %%
empty_string = "AI Engineer"
print(len(empty_string))
# Out:
# 11

# %%
s = "DataScience"
print(s[1:5])
# Out:
# ataS

# %%
ss = "DataScience"
print(ss(1:5))
# Out:
#   Cell In[7], line 2
#     print(s(1:5))
#              ^
# SyntaxError: invalid syntax
