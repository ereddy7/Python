# %%
base = 200
height = 12

area= height * base;
area
# Out:
# 2400

# %%
x =10
y= 3
x/y
# Out:
# 3.3333333333333335

# %%
x//y
# Out:
# 3

# %%
(x,y)
# Out:
# (10, 3)

# %%
x**y
# Out:
# 1000

# %%
10+2*3
# Out:
# 16

# %%
(10+2)*3
# Out:
# 36

# %%
-9 % 2
# Out:
# 1
